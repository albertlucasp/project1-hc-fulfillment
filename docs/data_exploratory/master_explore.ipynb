# %%
# !uv add pandas
import pandas as pd
from pathlib import Path
# Out:
# Resolved 106 packages in 1ms
# Audited 7 packages in 1ms

# %%
source_path = Path('/home/albert/project/project1-hc-fulfillment/data/raw/master_data')
dfs = [pd.read_csv(file) for file in source_path.glob('*.csv')]
dfs[0].head(n=10)
# Out:
#   employee_id    employee_name grade_level pay_grade job_code  \
# 0   E00000518    Utami Yuliana         G08       P07  J323297
# 1   E00002862    Teguh Yuliana         G03       P02  J784480
# 2   E00000476      Fajar Fauzi         G04       P03  J757746
# 3   E00000833    Teguh Hidayat         G07       P06  J127254
# 4   E00000767   Maya Anggraini         G06       P05  J764327
# 5   E00002628     Maya Santoso         G07       P06  J644237
# 6   E00000352      Utami Fauzi         G09       P08  J572161
# 7   E00002387      Adi Pratama         G07       P06  J708171
# 8   E00002454  Lestari Santoso         G04       P03  J986143
# 9   E00001677    Wahyu Pratama         G02       P01  J926341
#
#            job_title position_code  \
# 0  Sub Branch Leader     PST792905
# 1            Manager     PST468100
# 2       Senior Staff     PST123792
# 3       Senior Staff     PST738309
# 4        Assoc Staff     PST572780
# 5         Supervisor     PST770871
# ...

# %%
# Sample 1 of 12 data
df = dfs[0]

df.dtypes
# Out:
# employee_id                   str
# employee_name                 str
# grade_level                   str
# pay_grade                     str
# job_code                      str
# job_title                     str
# position_code                 str
# position_title                str
# area_code                     str
# area_name                     str
# subarea_code                  str
# subarea_name                  str
# org_unit_code                 str
# org_unit_name                 str
# employment_status_code        str
# employment_status_name        str
# employment_group_code         str
# employment_group_name         str
# employment_subgroup_code      str
# employment_subgroup_name      str
# gender                        str
# birth_date                    str
# birth_city                    str
# entry_program_code            str
# entry_program_name            str
# tax_number                  int64
# marital_status                str
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2690 entries, 0 to 2689
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   employee_id               2690 non-null   str
#  1   employee_name             2690 non-null   str
#  2   grade_level               2621 non-null   str
#  3   pay_grade                 2626 non-null   str
#  4   job_code                  2690 non-null   str
#  5   job_title                 2690 non-null   str
#  6   position_code             2690 non-null   str
#  7   position_title            2690 non-null   str
#  8   area_code                 2690 non-null   str
#  9   area_name                 2690 non-null   str
#  10  subarea_code              2690 non-null   str
#  11  subarea_name              2690 non-null   str
#  12  org_unit_code             2690 non-null   str
#  13  org_unit_name             2690 non-null   str
# ...
